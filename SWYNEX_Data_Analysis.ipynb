# %% [markdown]
# # **ONLINE RETAIL(Cleaning Process)**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-08b4712f-3a1b-4cac-8370-2fbc9b1acca1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08b4712f-3a1b-4cac-8370-2fbc9b1acca1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("online_retail_II.csv")
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.tail()
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID Country
# 1067366  2011-12-09 12:50:00   2.10      12680.0  France
# 1067367  2011-12-09 12:50:00   4.15      12680.0  France
# 1067368  2011-12-09 12:50:00   4.15      12680.0  France
# 1067369  2011-12-09 12:50:00   4.95      12680.0  France
# 1067370  2011-12-09 12:50:00  18.00      12680.0  France

# %%
df.shape
# Out:
# (1067371, 8)

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df['Invoice'].str.contains('[A-Za-z]').sum() #understanding why invoice is in object because there are some cancelled orders like C489449
# Out:
# np.int64(19500)

# %%
df[df['Invoice'].str.startswith('C')]['Quantity'].describe() #describing all cancelled invoice
# Out:
# count    19494.000000
# mean       -25.186827
# std        805.104908
# min     -80995.000000
# 25%         -6.000000
# 50%         -2.000000
# 75%         -1.000000
# max          1.000000
# Name: Quantity, dtype: float64

# %%
df[(df['Invoice'].str.startswith('C')) & (df['Quantity'] > 0)] #found a HUGE negative quantity: -80,995
df[df['Quantity'] == -80995]
# Out:
#          Invoice StockCode                  Description  Quantity  \
# 1065883  C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                  InvoiceDate  Price  Customer ID         Country
# 1065883  2011-12-09 09:27:00   2.08      16446.0  United Kingdom

# %%
df.duplicated().sum()
# Out:
# np.int64(34335)

# %%
df[df.duplicated()].head(10)
# Out:
#     Invoice StockCode                        Description  Quantity  \
# 371  489517     21912           VINTAGE SNAKES & LADDERS         1
# 383  489517     22130   PARTY CONE CHRISTMAS DECORATION          6
# 384  489517     22319  HAIRCLIPS FORTIES FABRIC ASSORTED        12
# 385  489517     21913     VINTAGE SEASIDE JIGSAW PUZZLES         1
# 386  489517     21821   GLITTER STAR GARLAND WITH BELLS          1
# 390  489517    84951A    S/4 PISTACHIO LOVEBIRD COASTERS         1
# 391  489517     21491    SET OF THREE VINTAGE GIFT WRAPS         1
# 394  489517     21912           VINTAGE SNAKES & LADDERS         1
# 657  489529     22028       PENNY FARTHING BIRTHDAY CARD        12
# 658  489529     22036             DINOSAUR BIRTHDAY CARD        12
#
#              InvoiceDate  Price  Customer ID         Country
# 371  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 383  2009-12-01 11:34:00   0.85      16329.0  United Kingdom
# ...

# %%
df = df.drop_duplicates() #Dropped duplicates

# %%
df.shape
# Out:
# (1033036, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1033036 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1033036 non-null  object
#  1   StockCode    1033036 non-null  object
#  2   Description  1028761 non-null  object
#  3   Quantity     1033036 non-null  int64
#  4   InvoiceDate  1033036 non-null  object
#  5   Price        1033036 non-null  float64
#  6   Customer ID  797885 non-null   float64
#  7   Country      1033036 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 70.9+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']) #Converted invoicedate to Datetime
# Out:
# /tmp/ipykernel_4696/2477866267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']) #Converted invoicedate to Datetime

# %%
df.info() #Checking whether invoicedate is changed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1033036 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1033036 non-null  object
#  1   StockCode    1033036 non-null  object
#  2   Description  1028761 non-null  object
#  3   Quantity     1033036 non-null  int64
#  4   InvoiceDate  1033036 non-null  datetime64[ns]
#  5   Price        1033036 non-null  float64
#  6   Customer ID  797885 non-null   float64
#  7   Country      1033036 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 70.9+ MB

# %%
df['Customer ID'] = df['Customer ID'].astype('Int64') #Converted customer_id from object to int
# Out:
# /tmp/ipykernel_4696/3591849433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Customer ID'] = df['Customer ID'].astype('Int64') #Converted customer_id from object to int

# %%
df.info() #Checking all the datatypes are in correct format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1033036 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1033036 non-null  object
#  1   StockCode    1033036 non-null  object
#  2   Description  1028761 non-null  object
#  3   Quantity     1033036 non-null  int64
#  4   InvoiceDate  1033036 non-null  datetime64[ns]
#  5   Price        1033036 non-null  float64
#  6   Customer ID  797885 non-null   Int64
#  7   Country      1033036 non-null  object
# dtypes: Int64(1), datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 71.9+ MB

# %%
df[df['Quantity'] == '-80995'] #Researching about quantity that has -80995 and checking whether this a type error
df[df['Quantity'] == '80995']
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country]
# Index: []

# %%
df[df['Quantity'] == '80995']
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country]
# Index: []

# %%
df['Quantity'].describe()  #quantity describe
# Out:
# count    1.033036e+06
# mean     1.007688e+01
# std      1.751976e+02
# min     -8.099500e+04
# 25%      1.000000e+00
# 50%      3.000000e+00
# 75%      1.000000e+01
# max      8.099500e+04
# Name: Quantity, dtype: float64

# %%
df[df['Quantity'].abs() == '80995' ]
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country]
# Index: []

# %%
df.sort_values('Quantity').head()#Found the quantity -80995
# Out:
#          Invoice StockCode                     Description  Quantity  \
# 1065883  C581484     23843     PAPER CRAFT , LITTLE BIRDIE    -80995
# 587085   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 750991    556691     23005    printing smudges/thrown away     -9600
# 303996    519017     22759                             NaN     -9600
# 750990    556690     23005    printing smudges/thrown away     -9600
#
#                 InvoiceDate  Price  Customer ID         Country
# 1065883 2011-12-09 09:27:00   2.08        16446  United Kingdom
# 587085  2011-01-18 10:17:00   1.04        12346  United Kingdom
# 750991  2011-06-14 10:37:00   0.00         <NA>  United Kingdom
# 303996  2010-08-13 09:14:00   0.00         <NA>  United Kingdom
# 750990  2011-06-14 10:37:00   0.00         <NA>  United Kingdom

# %%
df.sort_values('Quantity').tail() #and found the quantity 80995	understood the order is been cancelled
# Out:
#         Invoice StockCode                         Description  Quantity  \
# 127168   501534     21091         SET/6 WOODLAND PAPER PLATES     12960
# 127166   501534     21099         SET/6 STRAWBERRY PAPER CUPS     12960
# 90857    497946     37410  BLACK AND WHITE PAISLEY FLOWER MUG     19152
# 587080   541431     23166      MEDIUM CERAMIC TOP STORAGE JAR     74215
# 1065882  581483     23843         PAPER CRAFT , LITTLE BIRDIE     80995
#
#                 InvoiceDate  Price  Customer ID         Country
# 127168  2010-03-17 13:09:00   0.10        13902         Denmark
# 127166  2010-03-17 13:09:00   0.10        13902         Denmark
# 90857   2010-02-15 11:57:00   0.10        13902         Denmark
# 587080  2011-01-18 10:01:00   1.04        12346  United Kingdom
# 1065882 2011-12-09 09:15:00   2.08        16446  United Kingdom

# %%
df['cancelled'] = df['Invoice'].str.startswith('C') #Stored Cancelled orders in a column
# Out:
# /tmp/ipykernel_4696/3734688284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cancelled'] = df['Invoice'].str.startswith('C') #Stored Cancelled orders in a column

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4275
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    235151
# Country             0
# cancelled           0
# dtype: int64

# %%
df['Price'].eq(0).sum() #Checking price that is equal to 0
# Out:
# np.int64(6014)

# %%
df[df['Price'] < 0].head(10)
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
# 825444  A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 825445  A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#            Price  Customer ID         Country  cancelled
# 179403 -53594.36         <NA>  United Kingdom      False
# 276274 -44031.79         <NA>  United Kingdom      False
# 403472 -38925.87         <NA>  United Kingdom      False
# 825444 -11062.06         <NA>  United Kingdom      False
# 825445 -11062.06         <NA>  United Kingdom      False

# %%
df[df['Price'] == 0].head(10) #checking price value that has 0
# Out:
#      Invoice StockCode   Description  Quantity         InvoiceDate  Price  \
# 263   489464     21733  85123a mixed       -96 2009-12-01 10:52:00    0.0
# 283   489463     71477         short      -240 2009-12-01 10:52:00    0.0
# 284   489467    85123A   21733 mixed      -192 2009-12-01 10:53:00    0.0
# 470   489521     21646           NaN       -50 2009-12-01 11:44:00    0.0
# 3114  489655     20683           NaN       -44 2009-12-01 17:26:00    0.0
# 3161  489659     21350           NaN       230 2009-12-01 17:39:00    0.0
# 3162  489660     35956          lost     -1043 2009-12-01 17:43:00    0.0
# 3168  489663    35605A       damages      -117 2009-12-01 18:02:00    0.0
# 3731  489781     84292           NaN        17 2009-12-02 11:45:00    0.0
# 4296  489806     18010           NaN      -770 2009-12-02 12:42:00    0.0
#
#       Customer ID         Country  cancelled
# 263          <NA>  United Kingdom      False
# 283          <NA>  United Kingdom      False
# ...

# %%
zero_price = df[df['Price'] == 0]
df = df[df['Price'] != 0] #Keeps only the row where the price is not 0

# %%
df.shape
# Out:
# (1027022, 9)

# %%
df['Description'].isna().sum()#Checking description null values becomes 0 after deleting price that has 0 values.
                              #Most of the description has the price value 0
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    229207
# Country             0
# cancelled           0
# dtype: int64

# %%
df['Description'] = df['Description'].str.strip()#This removes extra spaces in description

# %%
df.head(5)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  cancelled
# 0 2009-12-01 07:45:00   6.95        13085  United Kingdom      False
# 1 2009-12-01 07:45:00   6.75        13085  United Kingdom      False
# 2 2009-12-01 07:45:00   6.75        13085  United Kingdom      False
# 3 2009-12-01 07:45:00   2.10        13085  United Kingdom      False
# 4 2009-12-01 07:45:00   1.25        13085  United Kingdom      False

# %%
df['Description'].nunique() #nunique() counts how many different values a column has, ignoring repeats.
# Out:
# 5373

# %%
Not_Products = df[df['StockCode'].str.contains('[0-9]') == False] #Investigating stockcode that aren't products

# %%
Not_Products['StockCode'].value_counts() #Not a Product List
# Out:
# StockCode
# POST            2079
# DOT             1418
# M               1380
# D                173
# S                101
# BANK CHARGES     100
# ADJUST            67
# AMAZONFEE         36
# DCGSSGIRL         23
# DCGSSBOY          21
# PADS              18
# CRUK              16
# B                  6
# m                  5
# Name: count, dtype: int64

# %% [markdown]
# **NON PRODUCTS**

# %%
df[df['StockCode'] == 'BANK CHARGES'].head(5)
# Out:
#        Invoice     StockCode   Description  Quantity         InvoiceDate  \
# 18410  C490943  BANK CHARGES  Bank Charges        -1 2009-12-08 14:08:00
# 18466   490948  BANK CHARGES  Bank Charges         1 2009-12-08 14:29:00
# 33435  C492206  BANK CHARGES  Bank Charges        -1 2009-12-15 16:32:00
# 55948  C494438  BANK CHARGES  Bank Charges        -1 2010-01-14 12:15:00
# 94431   498269  BANK CHARGES  Bank Charges         1 2010-02-17 15:03:00
#
#         Price  Customer ID         Country  cancelled
# 18410   15.00        16703  United Kingdom       True
# 18466   15.00        16805  United Kingdom      False
# 33435  848.43         <NA>  United Kingdom       True
# 55948  767.99         <NA>  United Kingdom       True
# 94431   15.00        16928  United Kingdom      False

# %%
df[df['StockCode'] == 'POST'].head(5)
# Out:
#      Invoice StockCode Description  Quantity         InvoiceDate   Price  \
# 89    489439      POST     POSTAGE         3 2009-12-01 09:28:00   18.00
# 126   489444      POST     POSTAGE         1 2009-12-01 09:55:00  141.00
# 173   489447      POST     POSTAGE         1 2009-12-01 10:10:00  130.00
# 625   489526      POST     POSTAGE         6 2009-12-01 11:50:00   18.00
# 927  C489538      POST     POSTAGE        -1 2009-12-01 12:18:00    9.58
#
#      Customer ID         Country  cancelled
# 89         12682          France      False
# 126        12636             USA      False
# 173        12362         Belgium      False
# 625        12533         Germany      False
# 927        15796  United Kingdom       True

# %%
df[df['StockCode'] == 'DOT'].head(5)
# Out:
#      Invoice StockCode     Description  Quantity         InvoiceDate   Price  \
# 2379  489597       DOT  DOTCOM POSTAGE         1 2009-12-01 14:28:00  647.19
# 2539  489600       DOT  DOTCOM POSTAGE         1 2009-12-01 14:43:00   55.96
# 2551  489601       DOT  DOTCOM POSTAGE         1 2009-12-01 14:44:00   68.39
# 2571  489602       DOT  DOTCOM POSTAGE         1 2009-12-01 14:45:00   59.35
# 2619  489603       DOT  DOTCOM POSTAGE         1 2009-12-01 14:46:00   42.39
#
#       Customer ID         Country  cancelled
# 2379         <NA>  United Kingdom      False
# 2539         <NA>  United Kingdom      False
# 2551         <NA>  United Kingdom      False
# 2571         <NA>  United Kingdom      False
# 2619         <NA>  United Kingdom      False

# %%
df[df['StockCode'] == 'M'].head(5)
# Out:
#       Invoice StockCode Description  Quantity         InvoiceDate    Price  \
# 2697   489609         M      Manual         1 2009-12-01 14:50:00     4.00
# 3053  C489651         M      Manual        -1 2009-12-01 16:48:00     5.10
# 5897  C489859         M      Manual        -1 2009-12-02 14:45:00    69.57
# 9259  C490126         M      Manual        -1 2009-12-03 18:12:00     5.95
# 9307  C490129         M      Manual        -1 2009-12-03 18:26:00  1998.49
#
#       Customer ID         Country  cancelled
# 2697         <NA>  United Kingdom      False
# 3053        17804  United Kingdom       True
# 5897         <NA>  United Kingdom       True
# 9259        15884  United Kingdom       True
# 9307        15482  United Kingdom       True

# %%
df[df['StockCode'] == 'D'].head(5)
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 735    C489535         D    Discount        -1 2009-12-01 12:11:00   9.00
# 736    C489535         D    Discount        -1 2009-12-01 12:11:00  19.00
# 24675  C491428         D    Discount        -1 2009-12-10 20:23:00   9.10
# 29414  C491845         D    Discount        -1 2009-12-14 14:54:00   1.59
# 29958  C491962         D    Discount        -1 2009-12-14 16:38:00   0.59
#
#        Customer ID         Country  cancelled
# 735          15299  United Kingdom       True
# 736          15299  United Kingdom       True
# 24675        15494  United Kingdom       True
# 29414         <NA>  United Kingdom       True
# 29958        13206  United Kingdom       True

# %%
df[df['StockCode'] == 'S'].head(5)
# Out:
#         Invoice StockCode Description  Quantity         InvoiceDate   Price  \
# 114061  C500305         S     SAMPLES        -1 2010-03-07 10:59:00   73.80
# 114083  C500309         S     SAMPLES        -1 2010-03-07 11:09:00   32.03
# 133558  C502083         S     SAMPLES        -1 2010-03-22 15:50:00  170.37
# 133582  C502088         S     SAMPLES        -1 2010-03-22 16:03:00  259.59
# 136253  C502438         S     SAMPLES        -1 2010-03-24 13:11:00  605.18
#
#         Customer ID         Country  cancelled
# 114061         <NA>  United Kingdom       True
# 114083         <NA>  United Kingdom       True
# 133558         <NA>  United Kingdom       True
# 133582         <NA>  United Kingdom       True
# 136253         <NA>  United Kingdom       True

# %%
df[df['StockCode'] == 'CRUK'].head(10)
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 842969  C564763      CRUK  CRUK Commission        -1 2011-08-30 10:49:00
# 849464  C565382      CRUK  CRUK Commission        -1 2011-09-02 15:45:00
# 859206  C566216      CRUK  CRUK Commission        -1 2011-09-09 15:17:00
# 864273  C566565      CRUK  CRUK Commission        -1 2011-09-13 12:32:00
# 876043  C567655      CRUK  CRUK Commission        -1 2011-09-21 14:40:00
# 887050  C568345      CRUK  CRUK Commission        -1 2011-09-26 15:28:00
# 898246  C569245      CRUK  CRUK Commission        -1 2011-10-03 09:57:00
# 915425  C570487      CRUK  CRUK Commission        -1 2011-10-10 17:12:00
# 927228  C571440      CRUK  CRUK Commission        -1 2011-10-17 13:31:00
# 941573  C572551      CRUK  CRUK Commission        -1 2011-10-24 17:07:00
#
#          Price  Customer ID         Country  cancelled
# 842969    1.60        14096  United Kingdom       True
# ...

# %%
df[df['StockCode'] == 'B'].head(5)
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
# 825443  A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 825444  A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
#
#            Price  Customer ID         Country  cancelled
# 179403 -53594.36         <NA>  United Kingdom      False
# 276274 -44031.79         <NA>  United Kingdom      False
# 403472 -38925.87         <NA>  United Kingdom      False
# 825443  11062.06         <NA>  United Kingdom      False
# 825444 -11062.06         <NA>  United Kingdom      False

# %%
df[df['StockCode'] == 'm']
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 96608   498492         m      Manual         1 2010-02-19 10:56:00   2.55
# 96609   498492         m      Manual         1 2010-02-19 10:56:00   3.40
# 157226  504396         m      Manual         1 2010-04-13 11:45:00   4.00
# 228780  511509         m      Manual         1 2010-06-08 15:26:00   2.55
# 565844  539736         m      Manual         1 2010-12-21 15:18:00   2.55
#
#         Customer ID         Country  cancelled
# 96608          <NA>  United Kingdom      False
# 96609          <NA>  United Kingdom      False
# 157226         <NA>  United Kingdom      False
# 228780         <NA>  United Kingdom      False
# 565844         <NA>  United Kingdom      False

# %%
df[df['StockCode'] == 'AMAZONFEE'].head(5)
# Out:
#         Invoice  StockCode Description  Quantity         InvoiceDate  \
# 440688  C531400  AMAZONFEE  AMAZON FEE        -1 2010-11-08 10:08:00
# 440698   531411  AMAZONFEE  AMAZON FEE         1 2010-11-08 10:11:00
# 517452  C537600  AMAZONFEE  AMAZON FEE        -1 2010-12-07 12:41:00
# 517953  C537630  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:04:00
# 517955   537632  AMAZONFEE  AMAZON FEE         1 2010-12-07 15:08:00
#
#            Price  Customer ID         Country  cancelled
# 440688   6706.71         <NA>  United Kingdom       True
# 440698   6706.71         <NA>  United Kingdom      False
# 517452      1.00         <NA>  United Kingdom       True
# 517953  13541.33         <NA>  United Kingdom       True
# 517955  13541.33         <NA>  United Kingdom      False

# %%
df[df['StockCode'] == 'ADJUST'].head(5)
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 70975   495732    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70976   495733    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70977   495735    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70978   495734    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70979  C495737    ADJUST  Adjustment by john on 26/01/2010 16        -1
#
#               InvoiceDate   Price  Customer ID         Country  cancelled
# 70975 2010-01-26 16:20:00   96.46         <NA>            EIRE      False
# 70976 2010-01-26 16:21:00   68.34        14911            EIRE      False
# 70977 2010-01-26 16:22:00  201.56        12745            EIRE      False
# 70978 2010-01-26 16:22:00  205.82        14911            EIRE      False
# 70979 2010-01-26 16:23:00   10.50        16154  United Kingdom       True

# %% [markdown]
# **REAL PRODUCTS**

# %%
df[df['StockCode'] == 'DCGSSGIRL'].head(5)
# Out:
#        Invoice  StockCode      Description  Quantity         InvoiceDate  \
# 244831  513099  DCGSSGIRL  GIRLS PARTY BAG         3 2010-06-21 15:13:00
# 246184  513200  DCGSSGIRL  GIRLS PARTY BAG         6 2010-06-22 16:28:00
# 249938  513574  DCGSSGIRL  GIRLS PARTY BAG         1 2010-06-25 15:13:00
# 251930  513655  DCGSSGIRL  GIRLS PARTY BAG         5 2010-06-28 10:02:00
# 253997  513907  DCGSSGIRL  GIRLS PARTY BAG         1 2010-06-29 12:08:00
#
#         Price  Customer ID         Country  cancelled
# 244831   3.36         <NA>  United Kingdom      False
# 246184   3.36         <NA>  United Kingdom      False
# 249938   3.36         <NA>  United Kingdom      False
# 251930   3.36         <NA>  United Kingdom      False
# 253997   3.36         <NA>  United Kingdom      False

# %%
df[df['StockCode'] == 'PADS'].head(10)
# Out:
#        Invoice StockCode                 Description  Quantity  \
# 62299   494914      PADS  PADS TO MATCH ALL CUSHIONS         1
# 74731   496222      PADS  PADS TO MATCH ALL CUSHIONS         1
# 77702   496473      PADS  PADS TO MATCH ALL CUSHIONS         1
# 79794   496643      PADS  PADS TO MATCH ALL CUSHIONS         1
# 90798   497935      PADS  PADS TO MATCH ALL CUSHIONS         1
# 97716   498562      PADS  PADS TO MATCH ALL CUSHIONS         1
# 101718  499056      PADS  PADS TO MATCH ALL CUSHIONS         1
# 104480  499399      PADS  PADS TO MATCH ALL CUSHIONS         1
# 123947  501176      PADS  PADS TO MATCH ALL CUSHIONS         1
# 156809  504332      PADS  PADS TO MATCH ALL CUSHIONS         1
#
#                InvoiceDate  Price  Customer ID         Country  cancelled
# 62299  2010-01-19 17:04:00  0.001        16705  United Kingdom      False
# 74731  2010-01-29 13:53:00  0.001        13583  United Kingdom      False
# ...

# %%
df[df['StockCode'] == 'DCGSSBOY'].head(5)
# Out:
#        Invoice StockCode     Description  Quantity         InvoiceDate  Price  \
# 244830  513099  DCGSSBOY  BOYS PARTY BAG         5 2010-06-21 15:13:00   3.36
# 246183  513200  DCGSSBOY  BOYS PARTY BAG         7 2010-06-22 16:28:00   3.36
# 249937  513574  DCGSSBOY  BOYS PARTY BAG         3 2010-06-25 15:13:00   3.36
# 251929  513655  DCGSSBOY  BOYS PARTY BAG         4 2010-06-28 10:02:00   3.36
# 278355  516470  DCGSSBOY  BOYS PARTY BAG         1 2010-07-20 15:28:00   3.36
#
#         Customer ID         Country  cancelled
# 244830         <NA>  United Kingdom      False
# 246183         <NA>  United Kingdom      False
# 249937         <NA>  United Kingdom      False
# 251929         <NA>  United Kingdom      False
# 278355         <NA>  United Kingdom      False

# %%
df['StockCode'] = df['StockCode'].str.upper() #changing the stockcode to uppercase

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1027022 entries, 0 to 1067370
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1027022 non-null  object
#  1   StockCode    1027022 non-null  object
#  2   Description  1027022 non-null  object
#  3   Quantity     1027022 non-null  int64
#  4   InvoiceDate  1027022 non-null  datetime64[ns]
#  5   Price        1027022 non-null  float64
#  6   Customer ID  797815 non-null   Int64
#  7   Country      1027022 non-null  object
#  8   cancelled    1027022 non-null  bool
# dtypes: Int64(1), bool(1), datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 72.5+ MB

# %%
non_products_list = ['POST', 'DOT', 'M', 'D', 'S', 'BANK CHARGES', 'ADJUST', 'AMAZONFEE', 'CRUK', 'B'] #make a list to store non products list

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    229207
# Country             0
# cancelled           0
# dtype: int64

# %%
df['Customer ID'].isna().sum()
# Out:
# np.int64(229207)

# %%
df.to_csv("cleaned_online_retail II.csv", index= False)

files.download("cleaned_online_retail II.csv")
